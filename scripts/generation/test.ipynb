# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import h5py

path='/home/asap7772/kun2/antmaze_gen/d4rl/gen_datasets_jan22'
which_dataset='Ant_maze_medium_test_noisy_multistart_False_multigoal_False.hdf5'
dataset = h5py.File(os.path.join(path, which_dataset), 'r')

# %%
xy = dataset['observations'][:, :2]
x, y = xy[:, 0], xy[:, 1]


print(x.shape, y.shape)
plt.plot(x.squeeze(),y.squeeze())
# Out:
# (100000,) (100000,)
